# %% [markdown]
# # **LEETCODE- BASIC IMPLEMENTATION**(Week 1- June)

# %% [markdown]
# # **HARITHA P V(MST03-0058)**

# %% [markdown]
# ## 1768. Merge Strings Alternately-You are given two strings word1 and word2. Merge the strings by adding letters in alternating order, starting with word1. If a string is longer than the other, append the additional letters onto the end of the merged string.

# %%
def mergeAlternately( word1, word2):

         n1=len(word1)
         n2=len(word2)
         res=""
         for i in range (max(n1, n2)):
           if i<n1:
            res +=word1[i]
           if i<n2:
            res +=word2[i]
         return res

# %%
mergeAlternately("abc","def")
# Out:
# 'adbecf'

# %%
mergeAlternately("abcd","pq")
# Out:
# 'apbqcd'

# %%
mergeAlternately("ab","pqrs")
# Out:
# 'apbqrs'

# %% [markdown]
# ## 389. Find the Difference-You are given two strings s and t.String t is generated by random shuffling string s and then add one more letter at a random position.Return the letter that was added to t.

# %%
def findTheDifference( s: str, t: str) -> str:
            for i in s:
                if s.count(i) != t.count(i):
                    return(i)

            for i in t:
                if t.count(i) != s.count(i):
                    return(i)

# %%
findTheDifference("a","ae")
# Out:
# 'e'

# %%
findTheDifference("abe","ab")
# Out:
# 'e'

# %%
findTheDifference("a","ab")
# Out:
# 'b'

# %% [markdown]
# ## 28. Find the Index of the First Occurrence in a String- Given two strings needle and haystack, return the index of the first occurrence of needle in haystack, or -1 if needle is not part of haystack.#

# %%
def strStr(haystack: str, needle: str) -> int:
    #if needle is empty, return 0
    if not needle:
        return 0

    len_h = len(haystack)
    len_n = len(needle)

    for i in range(len_h - len_n + 1):
        if haystack[i:i + len_n] == needle:
            return i

    return -1

# %%
strStr("hello","ll")
# Out:
# 2

# %%
strStr("aaaaa","bba")
# Out:
# -1

# %% [markdown]
# ## 242. Valid Anagram- Given two strings s and t, return true if t is an anagram of s, and false otherwise.An Anagram is a word or phrase formed by rearranging the letters of a different word or phrase, typically using all the original letters exactly once.

# %%
def isAnagram(s: str, t: str) -> bool:
  s= sorted(s)
  t= sorted(t)
  if len(s) != len(t):
    return False
  for i in range(len(s)):
    if s[i] != t[i]:
      return False
  return True

# %%
isAnagram("anagram","nagaram")
# Out:
# True

# %%
isAnagram("cat","rat")
# Out:
# False

# %% [markdown]
# ##459. Repeated Substring Pattern-Given a string s, check if it can be constructed by taking a substring of it and appending multiple copies of the substring together.

# %%
def repeatedSubstringPattern(s: str) -> bool:
  newstr= s+s
  newstr=newstr[1:-1]
  if s in newstr:
    return True
  else:
    return False

# %%
repeatedSubstringPattern('abab')
# Out:
# True

# %%
repeatedSubstringPattern('acd')
# Out:
# False

# %% [markdown]
# ## 283. Move Zeroes-Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.

# %%
def moveZeroes(nums):
  i,j=0,0
  while i<len(nums):
    if nums[i]!=0:
      nums[i],nums[j]=nums[j],nums[i]
      j+=1
    i+=1
  return nums

# %%
moveZeroes([0,1,0,3,12])
# Out:
# [1, 3, 12, 0, 0]

# %%
moveZeroes([0])
# Out:
# [0]

# %% [markdown]
# ## 66. Plus One-You are given a large integer represented as an integer array digits, where each digits[i] is the ith digit of the integer. The digits are ordered from most significant to least significant in left-to-right order. The large integer does not contain any leading 0's.Increment the large integer by one and return the resulting array of digits.

# %%
def plusOne(digits):
  l=len(digits)-1

  while l>= 0 and digits[l]==9:
      digits[l]=0
      l-=1
  if l<0:
      digits=[1]+digits

  else:
      digits[l]+=1
  return digits

# %%
plusOne([9])
# Out:
# [1, 0]

# %%
plusOne([1,2,3])
# Out:
# [1, 2, 4]

# %%
plusOne([9,9,9])
# Out:
# [1, 0, 0, 0]

# %% [markdown]
# ## 1822.Sign of the Product of an Array
# ##There is a function signFunc(x) that returns:
#
# ##1 if x is positive.
#
# ##-1 if x is negative.
#
# ##0 if x is equal to 0.
#
# ##You are given an integer array nums. Let product be the product of all values in the array nums.
#
# ##Return signFunc(product).

# %%
def arraySign(nums):
  sign=1
  for i in nums:
    if i==0:
      return 0
    elif i<0:
      sign*=-1
  return sign

# %%
arraySign([-1,-2,-3,-4,3,2,1])
# Out:
# 1

# %%
arraySign([1,1,2,0])
# Out:
# 0

# %%
arraySign([-1,1])
# Out:
# -1

# %% [markdown]
# ## 1502. Can Make Arithmetic Progression From Sequence- A sequence of numbers is called an arithmetic progression if the difference between any two consecutive elements is the same.Given an array of numbers arr, return true if the array can be rearranged to form an arithmetic progression. Otherwise, return false.

# %%
def canMakeArithmeticProgression(arr):
  arr.sort()
  d=arr[1]-arr[0]
  for i in range(2,len(arr)):
    if arr[i]-arr[i-1]!=d:
      return False
  return True

# %%
canMakeArithmeticProgression([3,5,1])
# Out:
# True

# %%
canMakeArithmeticProgression([1,2,4])
# Out:
# False

# %% [markdown]
# ## 896. Monotonic Array-An array is monotonic if it is either monotone increasing or monotone decreasing.
# ## An array nums is monotone increasing if for all i <= j, nums[i] <= nums[j]. An array nums is monotone decreasing if for all i <= j, nums[i] >= nums[j].
# ## Given an integer array nums, return true if the given array is monotonic, or false otherwise.

# %%
def isMonotonic(nums):
  increasing=True
  decreasing=True
  for i in range(1,len(nums)):
    if nums[i]<nums[i-1]:
      increasing=False
    if nums[i]>nums[i-1]:
      decreasing=False
  return  increasing or decreasing

# %%
isMonotonic([1,2,2,3])
# Out:
# True

# %%
isMonotonic([6,5,4,4])
# Out:
# True

# %%
isMonotonic([1,3,2])
# Out:
# False

# %% [markdown]
# ##13. Roman to Integer
# ##Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# ##Symbol                               Value
#
# ##I                                     1
#
# ##V                                     5
#
# ##X                                     10
#
# ##L                                     50
#
# ##C                                     100
#
# ##D                                     500
#
# ##M                                     1000
#
# ##For example, 2 is written as II in Roman numeral, just two ones added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# ##Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# ##I can be placed before V (5) and X (10) to make 4 and 9.
# ##X can be placed before L (50) and C (100) to make 40 and 90.
# ##C can be placed before D (500) and M (1000) to make 400 and 900.
# ##Given a roman numeral, convert it to an integer.

# %%
def romanToInt(s):
  roman={'I':1,'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000}
  res=0
  for i in range (len(s)-1):
    if roman[s[i]]<roman[s[i+1]]:
      res-=roman[s[i]]
    else:
      res+=roman[s[i]]

  return res+roman[s[-1]]

# %%
romanToInt('MCMXCIV')
# Out:
# 1989
